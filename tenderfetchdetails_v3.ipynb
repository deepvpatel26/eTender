# %%
from msilib.schema import Class
from pandas import options
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from PIL import Image
from PIL import Image, ImageFilter
import pytesseract
import base64
import urllib 
from selenium.webdriver.common.by import By
import numpy as np
import pandas as pd
import pyrebase
import pandas as pd
import csv
import time


from selenium.common.exceptions import NoSuchElementException

# %%
firebaseConfig = {
  "apiKey": "AIzaSyBca_j5rUCse7lyr-ydlSWt2UUIMFNJjqc",
  "authDomain": "app-tender.firebaseapp.com",
  "databaseURL": "https://app-tender-default-rtdb.firebaseio.com",
  "projectId": "app-tender",
  "storageBucket": "app-tender.appspot.com",
  "messagingSenderId": "261067565740",
  "appId": "1:261067565740:web:df9bd5499dba4e1eb44d09",
  "measurementId": "G-PWS7B0ER1D"
};
firebase=pyrebase.initialize_app(firebaseConfig)
db=firebase.database()

# %%
def check_exists_by_xpath(xpath):
    try:
        driver.find_elements_by_xpath(By.XPATH,xpath)
    except NoSuchElementException:
        return False
    return True

# %%
# options = Options()
# options.add_argument("--window-size=1920,1080")
# driver = webdriver.Chrome(options=options)

# driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")



# # try:
# # with open('D:\START-UP\eTender-main\captchaimg\mycapthca.png', 'wb') as file:
# #     file.write(driver.find_element(By.XPATH,"//img[@id='captchaImage']").screenshot_as_png)

# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
# res = ''
# eleSelected = False
# try:
#     while res == '' or str(eleSelected) == "None":
#         with open('D:\START-UP\eTender-main\captchaimg\mycapthca.png', 'wb') as file:
#             file.write(driver.find_element(By.XPATH,"//img[@id='captchaImage']").screenshot_as_png)

#         inputElement = driver.find_element(By.NAME,"Location")
#         inputElement.send_keys('Ahmedabad')
#         code = pytesseract.image_to_string(r'D:\START-UP\eTender-main\captchaimg\mycapthca.png')
#         res = ''.join(ch for ch in code if ch.isalnum())
#         inputElement = driver.find_element(By.NAME,"captchaText")
#         inputElement.send_keys(res)
        
#         if res != '':
#             folder = driver.find_element(By.XPATH,"//input[@id='submit']")
#             folder.click()
#             print("hi2")
#             # while eleSelected != True or eleSelected != False:
#             eleSelected= check_exists_by_xpath("//*[@id='content']/table/tbody/tr[2]/td/table/tbody/tr/td[2]/table/tbody/tr/td/table/tbody/tr/td/table/tbody/tr[6]/td/table/tbody/tr/td/span/b")
#             if str(eleSelected) == "None":
#                 print("hi3")
#                 driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
#                 continue
#             break
#         else:
#             driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
#         # driver.navigate().refresh()
#         # folder = driver.find_element(By.XPATH,"//button[@id='captcha']")
#         # folder.click()
        
#         print('hi')
#     print (res)

# except:
#     print ("An error occurred")

# %%
options = Options()
options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=options)

driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")



# try:
# with open('D:\START-UP\eTender-main\captchaimg\mycapthca.png', 'wb') as file:
#     file.write(driver.find_element(By.XPATH,"//img[@id='captchaImage']").screenshot_as_png)

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
res = ''
eleSelected = False
try:
    while res == '' or str(eleSelected) == "True":
        with open('captcha_image.img', 'wb') as file:
            file.write(driver.find_element(By.XPATH,"//img[@id='captchaImage']").screenshot_as_png)

        inputElement = driver.find_element(By.NAME,"Location")
        inputElement.send_keys('Ahmedabad')
        code = pytesseract.image_to_string(r'captcha_image.img')
        res = ''.join(ch for ch in code if ch.isalnum())
        inputElement = driver.find_element(By.NAME,"captchaText")
        inputElement.send_keys(res)
        
        if res != '':
            folder = driver.find_element(By.XPATH,"//input[@id='submit']")
            folder.click()
            print("hi2")
            # while eleSelected != True or eleSelected != False:
            # time.sleep(3)
            eleSelected= check_exists_by_xpath("//*[@id='content']/table/tbody/tr[2]/td/table/tbody/tr/td[2]/table/tbody/tr/td/table/tbody/tr/td/table/tbody/tr[6]/td/table/tbody/tr/td/span/b")
            print("gg",eleSelected)
            if str(eleSelected) == "True":
                print("hi3")
                driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
                continue
            break
        else:
            driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
        # driver.navigate().refresh()
        # folder = driver.find_element(By.XPATH,"//button[@id='captcha']")
        # folder.click()
        
        print('hi')
    print (res)

except Exception as e:
    print(e)
    # driver.close()
# Out:
# hi
# hi2
# 'WebDriver' object has no attribute 'find_elements_by_xpath'

# %%
options = Options()
options.add_argument("--window-size=1920,1080")
driver = webdriver.Chrome(options=options)

driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
res = ''
eleSelected = False
try:
    while res == '' or str(eleSelected) == "True":
        with open('captcha_image.png', 'wb') as file:
            file.write(driver.find_element(By.XPATH, "//img[@id='captchaImage']").screenshot_as_png)

        inputElement = driver.find_element(By.NAME, "Location")
        inputElement.send_keys('Mumbai')
        
        # Process captcha image with Tesseract OCR
        code = pytesseract.image_to_string(r'captcha_image.png')
        res = ''.join(ch for ch in code if ch.isalnum())
        
        inputElement = driver.find_element(By.NAME, "captchaText")
        inputElement.send_keys(res)
        
        if res != '':
            folder = driver.find_element(By.XPATH, "//input[@id='submit']")
            folder.click()
            print("hi2")
            
            # Check if the captcha was entered correctly
            try:
                eleSelected = driver.find_element(By.XPATH, "//*[@id='content']/table/tbody/tr[2]/td/table/tbody/tr/td[2]/table/tbody/tr/td/table/tbody/tr/td/table/tbody/tr[6]/td/table/tbody/tr/td/span/b")
                print("gg", eleSelected.text)
                if eleSelected.text == "True":
                    print("hi3")
                    driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
                    continue
            except NoSuchElementException:
                pass
            
            break
        else:
            driver.get("https://etenders.gov.in/eprocure/app;jsessionid=27BC7A64F887FDF6F74CA97EE7DFE34A.geps1?page=FrontEndTendersByLocation&service=page")
        print('hi')

    print(res)

except Exception as e:
    print(e)
# Out:
# hi
# hi
# hi2
# DNREND

# %%
# rows = driver.find_elements_by_xpath("//*[@class='list_table']/tbody/tr")
rows = driver.find_elements(by=By.XPATH, value="//*[@class='list_table']/tbody/tr")
# continue_link = driver.find_element_by_tag_name('a')
continue_link = driver.find_element(by=By.TAG_NAME, value='a')
elem = driver.find_elements(by=By.XPATH, value="//*[@href]")

list =[]

for i in range(0,len(rows)):
    list.append(elem)

arr = []
for index in range(0,len(rows)):
    # str = str(index     
    l=driver.find_element(By.XPATH,"//*[@class='list_table']/tbody/tr["+str(index)+"]/td")
    for i in l:
        arr.append(i.text)

np_arr = np.array(arr)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[31], line 15
#      12 arr = []
#      13 for index in range(0,len(rows)):
#      14     # str = str(index
# ---> 15     l=driver.find_element(By.XPATH,"//*[@class='list_table']/tbody/tr["+str(index)+"]/td")
#      16     for i in l:
#      17         arr.append(i.text)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class='list_table']/tbody/tr[0]/td"}
#   (Session info: chrome=124.0.6367.201); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6F8001522+60802]
# 	(No symbol) [0x00007FF6F7F7AC22]
# 	(No symbol) [0x00007FF6F7E37CE4]
# 	(No symbol) [0x00007FF6F7E86D4D]
# 	(No symbol) [0x00007FF6F7E86E1C]
# 	(No symbol) [0x00007FF6F7ECCE37]
# 	(No symbol) [0x00007FF6F7EAABBF]
# 	(No symbol) [0x00007FF6F7ECA224]
# 	(No symbol) [0x00007FF6F7EAA923]
# 	(No symbol) [0x00007FF6F7E78FEC]
# 	(No symbol) [0x00007FF6F7E79C21]
# 	GetHandleVerifier [0x00007FF6F83041BD+3217949]
# 	GetHandleVerifier [0x00007FF6F8346157+3488183]
# 	GetHandleVerifier [0x00007FF6F833F0DF+3459391]
# 	GetHandleVerifier [0x00007FF6F80BB8E6+823622]
# 	(No symbol) [0x00007FF6F7F85FBF]
# 	(No symbol) [0x00007FF6F7F80EE4]
# 	(No symbol) [0x00007FF6F7F81072]
# 	(No symbol) [0x00007FF6F7F718C4]
# 	BaseThreadInitThunk [0x00007FFC7CE9257D+29]
# 	RtlUserThreadStart [0x00007FFC7EBCAA48+40]

# %%
np_arr = np_arr.reshape(len(rows)-1,6)
df = pd.DataFrame(np_arr)

# %%
df = df.rename(columns=df.iloc[0])
df = df.drop(df.index[0])

# %%
# df.to_csv("Generated.csv",index=False)

# %%
arr = []
for index in range(1,len(rows)):
    # str = str(index     
    l=driver.find_elements_by_xpath ("//*[@class='list_table']/tbody/tr["+str(index)+"]/td")
    for i in l:
        arr.append(i.text)

np_arr = np.array(arr)
np_arr = np_arr.reshape(len(rows)-1,6)
df = pd.DataFrame(np_arr)
# Out:
# C:\Users\Kashish007\AppData\Local\Temp\ipykernel_612\1324425164.py:4: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   l=driver.find_elements_by_xpath ("//*[@class='list_table']/tbody/tr["+str(index)+"]/td")

# %%
print (len(rows))
# Out:
# 16

# %%
np_arr = np.array(arr)
np_arr = np_arr.reshape(len(rows)-1,6)

# %%
df = pd.DataFrame(np_arr)
df.head(100)
# Out:
#        0                     1                     2                     3  \
# 0   S.No      e-Published Date          Closing Date          Opening Date
# 1     1.  24-Feb-2022 04:00 PM  21-Mar-2022 03:00 PM  22-Mar-2022 03:30 PM
# 2     2.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 3     3.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 4     4.  21-Feb-2022 06:00 PM  07-Mar-2022 11:30 AM  08-Mar-2022 12:00 PM
# 5     5.  21-Feb-2022 06:00 PM  14-Mar-2022 12:00 PM  15-Mar-2022 12:30 PM
# 6     6.  18-Feb-2022 10:00 AM  14-Mar-2022 03:00 PM  16-Mar-2022 03:30 PM
# 7     7.  17-Feb-2022 06:00 PM  03-Mar-2022 11:30 AM  04-Mar-2022 12:00 PM
# 8     8.  17-Feb-2022 06:00 PM  03-Mar-2022 11:30 AM  04-Mar-2022 12:00 PM
# 9     9.  17-Feb-2022 05:00 PM  10-Mar-2022 11:00 AM  11-Mar-2022 11:30 AM
# 10   10.  14-Feb-2022 06:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 11   11.  14-Feb-2022 12:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 12   12.  14-Feb-2022 12:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 13   13.  09-Feb-2022 06:00 PM  05-Mar-2022 03:00 PM  07-Mar-2022 03:30 PM
# 14   14.  02-Feb-2022 05:00 PM  05-Mar-2022 03:00 PM  07-Mar-2022 03:30 PM
#
#                                                     4  \
# 0                         Title and Ref.No./Tender ID
# 1   [Design and Construction of Office Interior in...
# 2   [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 3   [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 4   [NIT 43 OF 21-22] [NIT 43 OF 21-22][2022_BSNL_...
# 5   [Cluster operation and Maintenance] [ATD/MM/T-...
# 6   [Providing Lease Vehicles for MAHSR Project fo...
# 7   [NIT 39 OF 21-22] [NIT 39 OF 21-22][2022_BSNL_...
# 8   [NIT 39 OF 21-22] [NIT 39 OF 21-22][2022_BSNL_...
# 9   [Schedule of Electric Works for Construction o...
# 10  [NIT 34 OF 21-22] [NIT 34 OF 21-22][2022_BSNL_...
# 11  [NIT 33 OF 21-22] [NIT 33 OF 21-22][2022_BSNL_...
# 12  [NIT 33 OF 21-22] [NIT 33 OF 21-22][2022_BSNL_...
# 13  [TENDER FOR LEASING OF VEHICLES FOR AHMEDABAD]...
# 14  [Work of Plantation of trees and its maintenan...
#
#                                                     5
# 0                                  Organisation Chain
# 1   National High Speed Rail Corporation Limited||...
# 2   Bharat Sanchar Nigam Limited (Govt of India En...
# 3   Bharat Sanchar Nigam Limited (Govt of India En...
# 4   Bharat Sanchar Nigam Limited (Govt of India En...
# 5   Bharat Sanchar Nigam Limited (Govt of India En...
# 6   National High Speed Rail Corporation Limited||...
# 7   Bharat Sanchar Nigam Limited (Govt of India En...
# 8   Bharat Sanchar Nigam Limited (Govt of India En...
# 9   National High Speed Rail Corporation Limited||...
# 10  Bharat Sanchar Nigam Limited (Govt of India En...
# 11  Bharat Sanchar Nigam Limited (Govt of India En...
# 12  Bharat Sanchar Nigam Limited (Govt of India En...
# 13  National High Speed Rail Corporation Limited||...
# 14  National High Speed Rail Corporation Limited||...

# %%
df = df.rename(columns=df.iloc[0])
df = df.drop(df.index[0])

# %%
df.rename(columns = {'e-Published Date':'e Published Date',
                     'Title and Ref.No./Tender ID':'Title and Ref No TenderID',
                     }, inplace = True)
df.columns
# Out:
# Index(['S.No', 'e Published Date', 'Closing Date', 'Opening Date',
#        'Title and Ref No TenderID', 'Organisation Chain'],
#       dtype='object')

# %%
df.head()
# Out:
#   S.No      e Published Date          Closing Date          Opening Date  \
# 1   1.  24-Feb-2022 04:00 PM  21-Mar-2022 03:00 PM  22-Mar-2022 03:30 PM
# 2   2.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 3   3.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 4   4.  21-Feb-2022 06:00 PM  07-Mar-2022 11:30 AM  08-Mar-2022 12:00 PM
# 5   5.  21-Feb-2022 06:00 PM  14-Mar-2022 12:00 PM  15-Mar-2022 12:30 PM
#
#                            Title and Ref No TenderID  \
# 1  [Design and Construction of Office Interior in...
# 2  [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 3  [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 4  [NIT 43 OF 21-22] [NIT 43 OF 21-22][2022_BSNL_...
# 5  [Cluster operation and Maintenance] [ATD/MM/T-...
#
#                                   Organisation Chain
# 1  National High Speed Rail Corporation Limited||...
# 2  Bharat Sanchar Nigam Limited (Govt of India En...
# 3  Bharat Sanchar Nigam Limited (Govt of India En...
# 4  Bharat Sanchar Nigam Limited (Govt of India En...
# 5  Bharat Sanchar Nigam Limited (Govt of India En...

# %%
df["Title and Ref No TenderID"][1]
# Out:
# '[Design and Construction of Office Interior including Civil, Horticulture,Electrical, S and T, MEP, HVAC and Fire Fighting works for NHSRCL in Building A of Sabarmati HUB Terminal.] [NHSRCL/ADI/2021-22/04][2022_NHSRC_107259_1]'

# %%
df["Tender_ID"] = None

# %%
for j in range(1, df.shape[0]+1):
    t = ""
    i=2
    l = len(df["Title and Ref No TenderID"][j])
    while df["Title and Ref No TenderID"][j][l-i] != "[":
        t = df["Title and Ref No TenderID"][j][l-i] + t
        i = i + 1
        df["Tender_ID"][j] = t 

t
# Out:
# '2022_NHSRC_101626_1'

# %%
# l = len(df["Title and Ref No TenderID"][3])
# while df["Title and Ref No TenderID"][3][l-i] != "[":
#     t = df["Title and Ref No TenderID"][3][l-i] + t
#     i = i + 1
#     # df["Tender_ID"][j] = t 
# t

# %%
df.head(20)
# Out:
#    S.No      e Published Date          Closing Date          Opening Date  \
# 1    1.  24-Feb-2022 04:00 PM  21-Mar-2022 03:00 PM  22-Mar-2022 03:30 PM
# 2    2.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 3    3.  22-Feb-2022 03:00 PM  08-Mar-2022 11:30 AM  09-Mar-2022 12:00 PM
# 4    4.  21-Feb-2022 06:00 PM  07-Mar-2022 11:30 AM  08-Mar-2022 12:00 PM
# 5    5.  21-Feb-2022 06:00 PM  14-Mar-2022 12:00 PM  15-Mar-2022 12:30 PM
# 6    6.  18-Feb-2022 10:00 AM  14-Mar-2022 03:00 PM  16-Mar-2022 03:30 PM
# 7    7.  17-Feb-2022 06:00 PM  03-Mar-2022 11:30 AM  04-Mar-2022 12:00 PM
# 8    8.  17-Feb-2022 06:00 PM  03-Mar-2022 11:30 AM  04-Mar-2022 12:00 PM
# 9    9.  17-Feb-2022 05:00 PM  10-Mar-2022 11:00 AM  11-Mar-2022 11:30 AM
# 10  10.  14-Feb-2022 06:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 11  11.  14-Feb-2022 12:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 12  12.  14-Feb-2022 12:00 PM  28-Feb-2022 11:30 AM  01-Mar-2022 12:00 PM
# 13  13.  09-Feb-2022 06:00 PM  05-Mar-2022 03:00 PM  07-Mar-2022 03:30 PM
# 14  14.  02-Feb-2022 05:00 PM  05-Mar-2022 03:00 PM  07-Mar-2022 03:30 PM
#
#                             Title and Ref No TenderID  \
# 1   [Design and Construction of Office Interior in...
# 2   [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 3   [NIT 45 OF 21-22] [NIT 45 OF 21-22][2022_BSNL_...
# 4   [NIT 43 OF 21-22] [NIT 43 OF 21-22][2022_BSNL_...
# 5   [Cluster operation and Maintenance] [ATD/MM/T-...
# 6   [Providing Lease Vehicles for MAHSR Project fo...
# 7   [NIT 39 OF 21-22] [NIT 39 OF 21-22][2022_BSNL_...
# 8   [NIT 39 OF 21-22] [NIT 39 OF 21-22][2022_BSNL_...
# 9   [Schedule of Electric Works for Construction o...
# 10  [NIT 34 OF 21-22] [NIT 34 OF 21-22][2022_BSNL_...
# 11  [NIT 33 OF 21-22] [NIT 33 OF 21-22][2022_BSNL_...
# 12  [NIT 33 OF 21-22] [NIT 33 OF 21-22][2022_BSNL_...
# 13  [TENDER FOR LEASING OF VEHICLES FOR AHMEDABAD]...
# 14  [Work of Plantation of trees and its maintenan...
#
#                                    Organisation Chain            Tender_ID
# 1   National High Speed Rail Corporation Limited||...  2022_NHSRC_107259_1
# 2   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106897_2
# 3   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106897_1
# 4   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106715_1
# 5   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106766_1
# 6   National High Speed Rail Corporation Limited||...  2022_NHSRC_106183_1
# 7   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106239_1
# 8   Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_106239_2
# 9   National High Speed Rail Corporation Limited||...  2022_NHSRC_106214_1
# 10  Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_105658_1
# 11  Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_105649_1
# 12  Bharat Sanchar Nigam Limited (Govt of India En...   2022_BSNL_105649_2
# 13  National High Speed Rail Corporation Limited||...  2022_NHSRC_105106_1
# 14  National High Speed Rail Corporation Limited||...  2022_NHSRC_101626_1

# %%
# df = pd.read_csv("Generated.csv")
#Push Data
# print(df.columns)
html1 = driver.page_source
k=0
for i in range(1,df.shape[0]+1):
  if i == 1:
    s = ""
    l = html1.find("DirectLink_0") + 52
    while html1[l] != ">" :
        s = s + html1[l] 
        l = l + 1
  else:
    path = "DirectLink_0" + "_" + str(k)   
    s = ""
    l = html1.find(path) + 54
    while html1[l] != ">" :
        s = s + html1[l] 
        l = l + 1
    k = k + 1


  s = "https://etenders.gov.in" + s
  s = s.replace("amp;","")
  s = s[:-1]
  # for j in df.columns: 
    # db.push(df[j][i])
  print(df['e Published Date'][i])
  data={"e Published Date":df['e Published Date'][i],
        "Closing Date":df['Closing Date'][i], 
        "Opening Date":df['Opening Date'][i],
        "Title and Ref No TenderID": df['Title and Ref No TenderID'][i],
        "Organisation Chain":df['Organisation Chain'][i],
        "DirectLink":s,
        "TenderId":df["Tender_ID"][i]}
  print(db.child("e-Procure").push(data)) #unique key is generated
# Out:
# 24-Feb-2022 04:00 PM
# {'name': '-MwpMdoQYEUOZuSN1jfV'}
# 22-Feb-2022 03:00 PM
# {'name': '-MwpMdtoLGzxLOb5Whgk'}
# 22-Feb-2022 03:00 PM
# {'name': '-MwpMdzBy_DTvL0Wi5Wd'}
# 21-Feb-2022 06:00 PM
# {'name': '-MwpMe3waJD0CnCnXbDJ'}
# 21-Feb-2022 06:00 PM
# {'name': '-MwpMe8hHzTs5tvCRaIl'}
# 18-Feb-2022 10:00 AM
# {'name': '-MwpMeDFxvPk4KZx-YX9'}
# 17-Feb-2022 06:00 PM
# {'name': '-MwpMeHYJNH104Y-Hyvv'}
# 17-Feb-2022 06:00 PM
# {'name': '-MwpMeNClNZusH9uuuCo'}
# 17-Feb-2022 05:00 PM
# {'name': '-MwpMeSuz97NltR2wimR'}
# 14-Feb-2022 06:00 PM
# {'name': '-MwpMeYfaSc13gyTXlEv'}
# 14-Feb-2022 12:00 PM
# {'name': '-MwpMedwMPI5PeQZQQJE'}
# 14-Feb-2022 12:00 PM
# {'name': '-MwpMeiaBEGLLm7FLRwV'}
# 09-Feb-2022 06:00 PM
# {'name': '-MwpMenMDBS9Q36h1Ldr'}
# 02-Feb-2022 05:00 PM
# {'name': '-MwpMesEtm91ZO7kzBQf'}

# %%
"https://etenders.gov.in/eprocure/app?component=%24DirectLink_0&page=FrontEndAdvancedSearchResult&service=direct&session=T&sp=SX4bRUTQNhCKG6jax2K42Bw%3D%3D"
